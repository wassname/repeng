# %%
from datasets import Dataset, load_dataset

# %%
# OK I considered using this dataset, but it's not even that well aligned for honesty, GPT4 has mainly labelled verbosity as honesty

ds = load_dataset("rngusry/UltraFeedback-honesty-preferences")['train']
honest_data = ds.filter(lambda x: x['chosen_score'] == 5 and x['rejected_score'] == 1)
print(len(ds), len(honest_data))
honest_data[0]
# Out:
# 200448 23542
# ...
